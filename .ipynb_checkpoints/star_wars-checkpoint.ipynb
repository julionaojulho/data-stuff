# %% [markdown]
# ## fivethirtyeight star wars survey
#
# main packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#plt.style.use('seaborn-deep')

# %%
star_wars = pd.read_csv("starwars.csv", encoding="ISO-8859-1")
star_wars.head()
# Out:
#   RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0          NaN                                           Response
# 1   3292879998                                                Yes
# 2   3292879538                                                 No
# 3   3292765271                                                Yes
# 4   3292763116                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1           Star Wars: Episode I  The Phantom Menace
# ...

# %% [markdown]
# Removing NaN from the first column

# %%
star_wars = star_wars[pd.notnull(star_wars['RespondentID'])]
str_key = list(star_wars.columns)
str_key
# Out:
# ['RespondentID',
#  'Have you seen any of the 6 films in the Star Wars franchise?',
#  'Do you consider yourself to be a fan of the Star Wars film franchise?',
#  'Which of the following Star Wars films have you seen? Please select all that apply.',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
#  'Which character shot first?',
# ...

# %%
yes_no = {"Yes":True,"No":False}
star_wars[str_key[1]] = star_wars[str_key[1]].map(yes_no)
star_wars[str_key[2]] = star_wars[str_key[2]].map(yes_no)

# %%
movie_mapping = {
    "Star Wars: Episode I  The Phantom Menace": True,
    np.nan: False,
    "Star Wars: Episode II  Attack of the Clones": True,
    "Star Wars: Episode III  Revenge of the Sith": True,
    "Star Wars: Episode IV  A New Hope": True,
    "Star Wars: Episode V The Empire Strikes Back": True,
    "Star Wars: Episode VI Return of the Jedi": True
}
for col in star_wars.columns[3:9]:
    star_wars[col] = star_wars[col].map(movie_mapping)

# %%
star_wars = star_wars.rename(columns={
        str_key[3]: "seen_1",
        str_key[4]: "seen_2",
        str_key[5]: "seen_3",
        str_key[6]: "seen_4",
        str_key[7]: "seen_5",
        str_key[8]: "seen_6"
        })

star_wars.head()
# Out:
#   RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 1   3292879998                                               True
# 2   3292879538                                              False
# 3   3292765271                                               True
# 4   3292763116                                               True
# 5   3292731220                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                               True
# 2                                                NaN
# 3                                              False
# 4                                               True
# 5                                               True
#
#   seen_1 seen_2 seen_3 seen_4 seen_5 seen_6  \
# 1   True   True   True   True   True   True
# 2  False  False  False  False  False  False
# 3   True   True   True  False  False  False
# ...

# %%
star_wars[star_wars.columns[9:15]] = star_wars[star_wars.columns[9:15]].astype(float)
star_wars = star_wars.rename(columns={
        str_key[9]: "ranking_1",
        str_key[10]: "ranking_2",
        str_key[11]: "ranking_3",
        str_key[12]: "ranking_4",
        str_key[13]: "ranking_5",
        str_key[14]: "ranking_6"
        })
star_wars.head()
# Out:
#   RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 1   3292879998                                               True
# 2   3292879538                                              False
# 3   3292765271                                               True
# 4   3292763116                                               True
# 5   3292731220                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                               True
# 2                                                NaN
# 3                                              False
# 4                                               True
# 5                                               True
#
#   seen_1 seen_2 seen_3 seen_4 seen_5 seen_6  ranking_1  \
# 1   True   True   True   True   True   True        3.0
# 2  False  False  False  False  False  False        NaN
# ...

# %%
star_wars[star_wars.columns[9:15]].mean()
# Out:
# ranking_1    3.732934
# ranking_2    4.087321
# ranking_3    4.341317
# ranking_4    3.272727
# ranking_5    2.513158
# ranking_6    3.047847
# dtype: float64

# %%
plt.bar(range(6),star_wars[star_wars.columns[9:15]].mean())
# Out:
# <Container object of 6 artists>

# %% [markdown]
# ## Rankings
#
# So far, we've cleaned up the data, renamed several columns, and computed the average ranking of each movie. As I suspected, it looks like the "original" movies are rated much more highly than the newer ones.

# %%
star_wars[star_wars.columns[3:9]].sum()
# Out:
# seen_1    673
# seen_2    571
# seen_3    550
# seen_4    607
# seen_5    758
# seen_6    738
# dtype: int64

# %%
plt.bar(range(6),star_wars[star_wars.columns[3:9]].sum())
# Out:
# <Container object of 6 artists>

# %% [markdown]
# ## View counts
#
# It appears that the original movies were seen by more respondents than the newer movies. This reinforces what we saw in the rankings, where the earlier movies seem to be more popular.

# %%
fans = star_wars[star_wars[str_key[2]] == True]
casuals = star_wars[star_wars[str_key[2]] == False]

# %%
labels = ["Star Wars: Episode I \n The Phantom Menace",
    "Star Wars: Episode II  \n Attack of the Clones",
    "Star Wars: Episode III  \n Revenge of the Sith",
    "Star Wars: Episode IV  \n A New Hope",
    "Star Wars: Episode V \n The Empire Strikes Back",
    "Star Wars: Episode VI \n Return of the Jedi"]
plt.figure(figsize=(9,5))
locs = np.arange(0,6)
offset_locs = locs + 0.35
plt.barh(bottom=locs,height=0.35,width=fans[fans.columns[3:9]].sum(),color='darkred')
plt.barh(bottom=offset_locs,height=0.35,width=casuals[casuals.columns[3:9]].sum(),color='darkgrey')
plt.legend(['True Fans','Filthy \nCasuals'],loc=7)
plt.yticks(locs, labels, rotation=0)
plt.xlabel('Total number of viewers')
#plt.grid(b=False)

# %%
plt.figure(figsize=(9,5))
locs = np.arange(0,6)
offset_locs = locs + 0.35
plt.barh(bottom=locs,height=0.35,width=5 - fans[fans.columns[9:15]].mean(),color='darkred')
plt.barh(bottom=offset_locs,height=0.35,width=5 - casuals[casuals.columns[9:15]].mean(),color='darkgray')
plt.legend(['True Fans','Filthy \nCasuals'])
plt.yticks(locs, labels, rotation=0)
plt.xlabel('Best movie - 1 (worst) to 5 (best)')
#plt.grid(b=False)

# %%
from matplotlib.cbook import get_sample_data


han_f = len([i for i in fans['Which character shot first?'] if i == 'Han'])
greedo_f = len([i for i in fans['Which character shot first?'] if i == 'Greedo'])
han_c = len([i for i in casuals['Which character shot first?'] if i == 'Han'])
greedo_c = len([i for i in casuals['Which character shot first?'] if i == 'Greedo'])
fan_t = han_f + greedo_f
casual_t = han_c + greedo_c
han_t = han_f + han_c
greedo_t = greedo_f + greedo_c
tt = han_t + greedo_t
han = [han_f/fan_t, han_c/casual_t, han_t/tt]
greedo = [greedo_f/fan_t, greedo_c/casual_t, greedo_t/tt]
fig = plt.figure(figsize=(16,10))
ax1 = fig.add_subplot(1,1,1)
ax1.barh(np.arange(3),han,height=0.35,color='#2b3334')
ax1.barh(np.arange(3),greedo,height=0.35,color='#5b9899',left=han)
ax1.set(ylim=[-0.25, 5],xlim=[0, 1])
ax1.set_xticklabels(['0%','20%','40%','60%','80%','100%'])
ax1.xaxis.set_ticks_position('none') 
ax1.yaxis.set_visible(False) 
im = plt.imread(get_sample_data('/home/julionaojulho/git/data-stuff/images/greedo.gif'))
newax = fig.add_axes([0.7, 0.505, 0.2, 0.38], anchor='E')
newax.imshow(im)
newax.axis('off')
im = plt.imread(get_sample_data('/home/julionaojulho/git/data-stuff/images/hansolo.gif'))
newax = fig.add_axes([0.105, 0.5, 0.2, 0.4], anchor='W')
newax.imshow(im)
newax.axis('off')
# Out:
# (-0.5, 765.5, 1499.5, -0.5)

# %%
labels = 'Han Solo','Greedo'
sizes_f = [han_f/fan_t,greedo_f/fan_t]
sizes_c = [han_c/casual_t,greedo_c/casual_t]
sizes_t = [han_t/tt, greedo_t/tt]
colors = ['#2b3334','#5b9899']

fig1 = plt.figure(figsize=(15,12))
fig1.text(0.1,0.74,'WHO\nSHOT\nFIRST?',fontsize=100,color='k',
          weight='bold',multialignment='center')
fig1.text(0.5,0.84,'Well, that\'s actually an open topic with \na broad spectre.\
For instance, there are\nthose who think Han shot first (nice,\nreasonable people) and those \
who think\nGreedo shot first (we call them wrong).',
          fontsize=32,color='k',multialignment='left')
fig1.text(0.2,0.65,'Hence, the undisputed result:',
          fontsize=32,color='k',multialignment='left')
fig1.text(0.95,0.44,'What? I mean, who even\nare those people?',
          weight='bold',fontsize=30,color='k',multialignment='left')
fig1.text(1,0.29,'Han Solo is a fictional\ncharacter \
and the closest\ndepiction of "the Fonzie"\nin space.',
          fontsize=24,color='k',multialignment='left')
fig1.text(1,0.12,'Greedo is a green,\nrubbery alien thing\n\
that defintely did not\nshoot first.',
          fontsize=24,color='k',multialignment='left')

ax1 = fig1.add_subplot(3,3,6)
ax1.pie(sizes_f, colors=colors,
        autopct='%1.1f%%', shadow=True)
ax1.text(-0.7, 1.05,'True Fans',
        fontsize=25, color='k',multialignment='center')
centre_circle = plt.Circle((0,0),0.75,color='black',
                           fc='white',linewidth=1.25)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.axis('equal')

ax2 = plt.subplot2grid((3,3),(1,0),rowspan=2,colspan=2)#fig1.add_subplot(3,3,5)
ax2.pie(sizes_t, colors=colors,
        shadow=True,startangle=60)#wedgeprops={'linewidth':3})
ax2.text(-1.2, 0.8, 'Han Solo',
        fontsize=30, color='#2b3334')
ax2.text(-0.5, 0.4, '62,3%',
        fontsize=30, color='#2b3334')
ax2.text(0.8, -0.8, 'Greedo',
        fontsize=30, color='#5b9899')
ax2.text(0.2, -0.4, '37,7%',
        fontsize=30, color='#5b9899')
        
#draw a circle at the center of pie to make it look like a donut
centre_circle = plt.Circle((0,0),0.75,color='black',
                           fc='white',linewidth=1.25)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.axis('equal')

ax3 = fig1.add_subplot(3,3,9)
ax3.pie(sizes_c, colors=colors,
        autopct='%1.1f%%', shadow=True)
ax3.text(-0.85, 1.05, 'Filthy Casuals',
        fontsize=25, color='k',multialignment='center')
        
#draw a circle at the center of pie to make it look like a donut
centre_circle = plt.Circle((0,0),0.75,color='black',
                           fc='white',linewidth=1.25)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.axis('equal')

im = plt.imread(get_sample_data('/home/julionaojulho/git/data-stuff/images/greedo.gif'))
newax = fig.add_axes([0.4, 0.2, 0.22, 0.22], anchor='E')
newax.imshow(im)
newax.axis('off')
im = plt.imread(get_sample_data('/home/julionaojulho/git/data-stuff/images/hansolo.gif'))
newax = fig.add_axes([0.1, 0.35, 0.22, 0.22], anchor='W')
newax.imshow(im)
newax.axis('off')
im = plt.imread(get_sample_data('/home/julionaojulho/git/data-stuff/images/han_icon.gif'))
newax = fig.add_axes([0.9, 0.29, 0.15, 0.13], anchor='W')
newax.imshow(im)
newax.axis('off')
im = plt.imread(get_sample_data('/home/julionaojulho/git/data-stuff/images/greedo.png'))
newax = fig.add_axes([0.86, 0.1, 0.15, 0.15], anchor='E')
newax.imshow(im)
newax.axis('off')
# Out:
# (-0.5, 699.5, 699.5, -0.5)
